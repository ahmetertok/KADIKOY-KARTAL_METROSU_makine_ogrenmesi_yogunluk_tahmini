# %%
import pandas as pd
import numpy as np

# %%
raw_df = pd.read_csv(filepath_or_buffer='hourly_transportation_202009.csv')

# %%
raw_df
# Out:
#                  DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 0      2020-09-15 09:00:00                  3               DENİZ
# 1      2020-09-16 09:00:00                  2                 RAY
# 2      2020-09-15 12:00:00                  2                 RAY
# 3      2020-09-06 13:00:00                  1            KARAYOLU
# 4      2020-09-26 13:00:00                  2                 RAY
# ...                    ...                ...                 ...
# 22184  2020-09-28 12:00:00                  3               DENİZ
# 22185  2020-09-29 23:00:00                  2                 RAY
# 22186  2020-09-08 13:00:00                  2                 RAY
# 22187  2020-09-20 23:00:00                  2                 RAY
# 22188  2020-09-10 10:00:00                  2                 RAY
#
#                              LINE  TRANSFER_TYPE_ID TRANSFER_TYPE  \
# 0                     MOTOR TEKNE                 2       AKTARMA
# ...

# %%
new_df=raw_df[raw_df['LINE'].str.contains('KADIKÖY-KARTAL METROSU')]

# %%
new_df
# Out:
#                  DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 459    2020-09-09 14:00:00                  2                 RAY
# 487    2020-09-04 22:00:00                  2                 RAY
# 490    2020-09-05 17:00:00                  2                 RAY
# 499    2020-09-01 15:00:00                  2                 RAY
# 502    2020-09-05 19:00:00                  2                 RAY
# ...                    ...                ...                 ...
# 22108  2020-09-30 00:00:00                  2                 RAY
# 22135  2020-09-30 20:00:00                  2                 RAY
# 22144  2020-09-30 15:00:00                  2                 RAY
# 22163  2020-09-30 14:00:00                  2                 RAY
# 22165  2020-09-30 03:00:00                  2                 RAY
#
#                          LINE  TRANSFER_TYPE_ID TRANSFER_TYPE  \
# 459    KADIKÖY-KARTAL METROSU                 2        NORMAL
# ...

# %%
new_df.sort_values(by=['DATE_TIME'])
# Out:
#                  DATE_TIME  TRANSPORT_TYPE_ID TRANSPORT_TYPE_DESC  \
# 18706  2020-09-01 00:00:00                  2                 RAY
# 13855  2020-09-01 00:00:00                  2                 RAY
# 4626   2020-09-01 02:00:00                  2                 RAY
# 18720  2020-09-01 03:00:00                  2                 RAY
# 18493  2020-09-01 04:00:00                  2                 RAY
# ...                    ...                ...                 ...
# 19272  2020-09-30 21:00:00                  2                 RAY
# 19461  2020-09-30 22:00:00                  2                 RAY
# 5010   2020-09-30 22:00:00                  2                 RAY
# 4887   2020-09-30 23:00:00                  2                 RAY
# 1336   2020-09-30 23:00:00                  2                 RAY
#
#                          LINE  TRANSFER_TYPE_ID TRANSFER_TYPE  \
# 18706  KADIKÖY-KARTAL METROSU                 2        NORMAL
# ...

# %%
new_df2 = new_df.groupby(by="DATE_TIME")["NUMBER_OF_PASSENGER"].sum()

# %%
new_df2
# Out:
# DATE_TIME
# 2020-09-01 00:00:00      41
# 2020-09-01 02:00:00       1
# 2020-09-01 03:00:00       3
# 2020-09-01 04:00:00       4
# 2020-09-01 05:00:00     283
#                        ...
# 2020-09-30 19:00:00    9971
# 2020-09-30 20:00:00    5338
# 2020-09-30 21:00:00    3566
# 2020-09-30 22:00:00    2734
# 2020-09-30 23:00:00    1579
# Name: NUMBER_OF_PASSENGER, Length: 662, dtype: int64

# %%
new_df2.to_csv('/root/staj/eylul.csv')
